# %%
try:
    import pandas as pd
    print("Библиотека 'pandas' установлена!")
    print(f"Версия pandas: {pd.__version__}")
except ImportError as e:
    print(f"Ошибка: {e}. Библиотека не установлена.")
    print("Установите библиотеки командой: pip install requests pandas")
    exit()
# Out:
# Библиотека 'pandas' установлена!
# Версия pandas: 2.2.2

# %%
data = pd.read_csv('hh_vacancies_test.csv')
data
# Out:
#                                              Название  \
# 0                       Chief Technical Officer (CTO)
# 1        Директор по информационным технологиям (CIO)
# 2                        QA Manual/Ручной тестировщик
# 3                   Владелец продукта / Product owner
# 4                         Frontend-разработчик Vue.js
# ...                                               ...
# 1138     QA Automation Engineer (Java)/AI QA Engineer
# 1139  Assistant Professor - Data Science&AI (english)
# 1140            Senior Python developer (ML engineer)
# 1141                      Senior ML Platform Engineer
# 1142               MLOps инженер/ML Platform Engineer
#
#                             Компания  Зарплата (от)  Зарплата (до) Валюта  \
# 0                            IDF Lab            NaN            NaN    NaN
# 1                   StaffRecruitment       800000.0            NaN    RUR
# 2                           Эмбедика            NaN            NaN    NaN
# ...

# %%
data1 = pd.read_csv('hh_1.csv')
data1
# Out:
#                                              Название  \
# 0                       Chief Technical Officer (CTO)
# 1        Директор по информационным технологиям (CIO)
# 2                        QA Manual/Ручной тестировщик
# 3                   Владелец продукта / Product owner
# 4                         Frontend-разработчик Vue.js
# ...                                               ...
# 1138     QA Automation Engineer (Java)/AI QA Engineer
# 1139  Assistant Professor - Data Science&AI (english)
# 1140            Senior Python developer (ML engineer)
# 1141                      Senior ML Platform Engineer
# 1142               MLOps инженер/ML Platform Engineer
#
#                             Компания  Зарплата (от)  Зарплата (до) Валюта  \
# 0                            IDF Lab            NaN            NaN    NaN
# 1                   StaffRecruitment       800000.0            NaN    RUR
# 2                           Эмбедика            NaN            NaN    NaN
# ...

# %%
data2 = pd.read_csv('hh_vacancies_20250325_2040.csv')
data2
# Out:
#       ID вакансии                                         Название  \
# 0       118783133                    Chief Technical Officer (CTO)
# 1       115948874     Директор по информационным технологиям (CIO)
# 2       115741310                     QA Manual/Ручной тестировщик
# 3       118497533                Владелец продукта / Product owner
# 4       118492380                      Frontend-разработчик Vue.js
# ...           ...                                              ...
# 1138    118123714     QA Automation Engineer (Java)/AI QA Engineer
# 1139     81857296  Assistant Professor - Data Science&AI (english)
# 1140    117938544            Senior Python developer (ML engineer)
# 1141    112058497                      Senior ML Platform Engineer
# 1142    115441581               MLOps инженер/ML Platform Engineer
#
#                             Компания  Зарплата (от)  Зарплата (до) Валюта  \
# 0                            IDF Lab            NaN            NaN    NaN
# ...
